# %% [markdown]
# # Problem set - DEM
#
#
# ### Stylised facts of the business cycle

# %%
pip install fredapi
# Out:
# Collecting fredapi
#   Downloading fredapi-0.5.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: pandas in c:\users\michela\anaconda3\lib\site-packages (from fredapi) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\michela\anaconda3\lib\site-packages (from pandas->fredapi) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\michela\anaconda3\lib\site-packages (from pandas->fredapi) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\michela\anaconda3\lib\site-packages (from pandas->fredapi) (1.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\michela\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->fredapi) (1.15.0)
# Installing collected packages: fredapi
# Successfully installed fredapi-0.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
from fredapi import Fred
fred = Fred(api_key='25400ff00f45200a6b52344af538c912')

# %% [markdown]
# # Table 1

# %% [markdown]
# ## Recreating the table
# Getting the values for CND non-durable consumption, CD durable
# consumption, H total hours worked, AveH average hours worked per employee, L employment,
# GNP/L productivity, AveW average hourly wage based on national accounts.

# %%
gnp = fred.get_series('GNP', observation_start = '1964-01-01', observation_end = '2022-01-01', frequency = "q")
gnp.name = 'gnp'
gnp.tail()
# Out:
# 2021-01-01    22511.170
# 2021-04-01    23192.674
# 2021-07-01    23718.255
# 2021-10-01    24530.587
# 2022-01-01    24929.184
# Name: gnp, dtype: float64

# %%
gnp
# Out:
# 1964-01-01      674.880
# 1964-04-01      683.549
# 1964-07-01      697.079
# 1964-10-01      702.017
# 1965-01-01      723.225
#                 ...
# 2022-01-01    24929.184
# 2022-04-01    25456.409
# 2022-07-01    25885.432
# 2022-10-01    26289.489
# 2023-01-01    26592.668
# Name: gnp, Length: 237, dtype: float64

# %%
pcend = fred.get_series('PCEND', observation_start = '1964-01-01', observation_end = '2022-01-01', frequency = "q") # non durable consumption
pcend.name = 'pcend'

# %%
pcedg = fred.get_series('PCEDG', observation_start = '1964-01-01', observation_end = '2022-01-01', frequency = "q") # durable consumption
pcedg.name = 'pcedg'

# %%
h = fred.get_series('LNU02032200', observation_start = '1964-01-01', observation_end = '2022-01-01', frequency = "q") # Total At Work in Nonagricultural Industries
h.name = 'hours_worked'

# %%
ave_h = fred.get_series('M08304USM310NNBR', observation_start = '1964-01-01', observation_end = '2022-01-01', frequency = "q") #  Average Hours of Work Per Week, Nonagricultural Employment, Household Survey for United States
ave_h.name = 'average_worked'

# %%
l = fred.get_series('CE16OV', observation_start = '1964-01-01', observation_end = '2022-01-01', frequency = "q") # Employment level
l.name = 'employment'

# %%
gnp_l = gnp / l
gnp_l.name = 'productivity'

# %%
ave_w = fred.get_series('AHETPI', observation_start = '1964-01-01', observation_end = '2022-01-01', frequency = "q") # Average Hourly Earnings of Production and Nonsupervisory Employees
ave_w.name = 'average_wage'

# %%
pop = pd.concat([gnp, pcend, h, l, pcedg, ave_h, gnp_l, ave_w], axis = 1)
pop
# Out:
#                   gnp   pcend  hours_worked  employment   pcedg  \
# 1964-01-01    674.880   148.6        6747.0     68614.0    58.0
# 1964-04-01    683.549   151.5        6788.0     69402.0    59.5
# 1964-07-01    697.079   154.9        5225.0     69480.0    61.3
# 1964-10-01    702.017   155.8        7033.0     69710.0    59.4
# 1965-01-01    723.225   157.8        6903.0     70188.0    64.9
# ...               ...     ...           ...         ...     ...
# 2021-01-01  22511.170  3274.4       18605.0    150276.0  1990.9
# 2021-04-01  23192.674  3416.4       19199.0    151446.0  2113.5
# 2021-07-01  23718.255  3482.1       18968.0    153287.0  2035.0
# 2021-10-01  24530.587  3572.1       20676.0    155337.0  2101.6
# 2022-01-01  24929.184  3659.3       20543.0    157680.0  2183.8
#
#             average_worked  productivity  average_wage
# 1964-01-01            39.6      0.009836          2.50
# 1964-04-01            40.1      0.009849          2.52
# 1964-07-01            40.4      0.010033          2.55
# 1964-10-01            40.2      0.010071          2.56
# 1965-01-01            40.0      0.010304          2.59
# ...                    ...           ...           ...
# 2021-01-01             NaN      0.149799         25.26
# 2021-04-01             NaN      0.153142         25.66
# 2021-07-01             NaN      0.154731         26.12
# 2021-10-01             NaN      0.157919         26.59
# 2022-01-01             NaN      0.158100         26.99
#
# [233 rows x 8 columns]

# %%
tabella = pop.transpose()

# %%
tab = tabella[['2006-04-01']]
tab
# Out:
#                    2006-04-01
# gnp              13802.877000
# pcend             2076.800000
# hours_worked     19105.000000
# employment      144068.000000
# pcedg             1149.200000
# average_worked            NaN
# productivity         0.095808
# average_wage        16.670000

# %%
selected_values = tabella.loc[:,'2006-04-01':'2008-04-01']
selected_values
# Out:
#                    2006-04-01     2006-07-01     2006-10-01     2007-01-01  \
# gnp              13802.877000   13906.646000   14083.697000   14258.594000
# pcend             2076.800000    2112.900000    2092.800000    2129.100000
# hours_worked     19105.000000   17913.000000   20338.000000   20036.000000
# employment      144068.000000  144547.000000  145606.000000  146135.000000
# pcedg             1149.200000    1160.500000    1169.400000    1179.000000
# average_worked            NaN            NaN            NaN            NaN
# productivity         0.095808       0.096208       0.096725       0.097571
# average_wage        16.670000      16.820000      16.990000      17.150000
#
#                    2007-04-01     2007-07-01     2007-10-01     2008-01-01  \
# gnp              14463.277000   14681.751000   14875.943000   14857.342000
# pcend             2166.100000    2188.200000    2232.600000    2252.900000
# hours_worked     19424.000000   18196.000000   20019.000000   19522.000000
# employment      145851.000000  145944.000000  146271.000000  146207.000000
# pcedg             1185.700000    1191.900000    1195.600000    1153.500000
# average_worked            NaN            NaN            NaN            NaN
# productivity         0.099165       0.100599       0.101701       0.101619
# average_wage        17.340000      17.500000      17.630000      17.810000
#
#                    2008-04-01
# gnp              15023.210000
# pcend             2305.800000
# hours_worked     19226.000000
# employment      145926.000000
# pcedg             1137.700000
# average_worked            NaN
# productivity         0.102951
# average_wage        17.980000

# %%
std_dev = np.std(selected_values)

# %%
selected_values.loc['Standard Deviation'] = std_dev
selected_values
# Out:
# C:\Users\Michela\anaconda3\lib\site-packages\pandas\core\indexing.py:1700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, v, pi)
#                     2006-04-01 00:00:00  2006-07-01 00:00:00  \
# gnp                        13802.877000         13906.646000
# pcend                       2076.800000          2112.900000
# hours_worked               19105.000000         17913.000000
# employment                144068.000000        144547.000000
# pcedg                       1149.200000          1160.500000
# average_worked                      NaN                  NaN
# productivity                   0.095808             0.096208
# average_wage                  16.670000            16.820000
# Standard Deviation         46290.380680         46474.692489
#
#                     2006-10-01 00:00:00  2007-01-01 00:00:00  \
# gnp                        14083.697000         14258.594000
# pcend                       2092.800000          2129.100000
# hours_worked               20338.000000         20036.000000
# employment                145606.000000        146135.000000
# pcedg                       1169.400000          1179.000000
# average_worked                      NaN                  NaN
# productivity                   0.096725             0.097571
# average_wage                  16.990000            17.150000
# Standard Deviation         46752.517840         46923.912999
#
#                     2007-04-01 00:00:00  2007-07-01 00:00:00  \
# gnp                        14463.277000         14681.751000
# pcend                       2166.100000          2188.200000
# hours_worked               19424.000000         18196.000000
# employment                145851.000000        145944.000000
# pcedg                       1185.700000          1191.900000
# average_worked                      NaN                  NaN
# productivity                   0.099165             0.100599
# average_wage                  17.340000            17.500000
# Standard Deviation         46834.227973         46888.823329
#
#                     2007-10-01 00:00:00  2008-01-01 00:00:00  \
# gnp                        14875.943000         14857.342000
# pcend                       2232.600000          2252.900000
# hours_worked               20019.000000         19522.000000
# employment                146271.000000        146207.000000
# pcedg                       1195.600000          1153.500000
# average_worked                      NaN                  NaN
# productivity                   0.101701             0.101619
# average_wage                  17.630000            17.810000
# Standard Deviation         46934.875660         46929.264059
#
#                     2008-04-01 00:00:00  Standard Deviation
# gnp                        15023.210000                 NaN
# pcend                       2305.800000                 NaN
# hours_worked               19226.000000                 NaN
# employment                145926.000000                 NaN
# pcedg                       1137.700000                 NaN
# average_worked                      NaN                 NaN
# productivity                   0.102951                 NaN
# average_wage                  17.980000                 NaN
# Standard Deviation         46835.111353                 NaN

# %% [markdown]
# # Table 2

# %% [markdown]
# ## Recreating the table
# Getting the values for Y per capita output, C per capita consumption, I per capita investment, N
# per capita hours, w the real wage (compensation per hour), r the real interest rate, and A total
# factor productivity.

# %%
y = fred.get_series('PRS85006161', observation_start = '1982-01-01', observation_end = '2022-01-01', frequency = "q") # Output per capita
y.name = 'output_per_capita'

# %%
c = fred.get_series('A794RX0Q048SBEA', observation_start = '1982-01-01', observation_end = '2022-01-01', frequency = "q") # Consumption per capita
c.name = 'consumption_per_capita'

# %%
i = fred.get_series('A795RC0Q052SBEA', observation_start = '1982-01-01', observation_end = '2022-01-01', frequency = "q") # Investment per capita
i.name = 'investment_per_capita'

# %%
n = fred.get_series('M08304USM310NNBR', observation_start = '1982-01-01', observation_end = '2022-01-01', frequency = "q") #  Average Hours of Work Per Week, Nonagricultural Employment, Household Survey for United States
n.name = 'hours_per_capita'

# %%
r = fred.get_series('REAINTRATREARAT10Y', observation_start = '1982-01-01', observation_end = '2022-01-01', frequency = "q") # Real interest filter
r.name = 'real_interest_rate'

# %%
#a = fred.get_series('CTFPPPUSA669NRUG', observation_start = '1982-01-01', observation_end = '2022-01-01', frequency = "q") # 
#a.name = 'total_factor_productivity'

# %%
pap = pd.concat([y, c, i, n, r], axis = 1)
pap
# Out:
#             output_per_capita  consumption_per_capita  investment_per_capita  \
# 1982-01-01               -3.5                 18711.0                 1065.0
# 1982-04-01               -1.1                 18726.0                 1075.0
# 1982-07-01               -1.5                 18804.0                 1084.0
# 1982-10-01                0.2                 19086.0                 1134.0
# 1983-01-01                3.3                 19236.0                 1151.0
# ...                       ...                     ...                    ...
# 2021-01-01                6.6                 40323.0                 5997.0
# 2021-04-01                4.8                 41468.0                 6363.0
# 2021-07-01                0.5                 41730.0                 6121.0
# 2021-10-01                1.7                 42014.0                 6315.0
# 2022-01-01               -1.2                 42130.0                 6559.0
#
#             hours_per_capita  real_interest_rate
# 1982-01-01               NaN            7.469795
# 1982-04-01               NaN            7.357922
# 1982-07-01               NaN            6.982003
# 1982-10-01               NaN            5.929036
# 1983-01-01               NaN            5.659644
# ...                      ...                 ...
# 2021-01-01               NaN           -0.151111
# 2021-04-01               NaN            0.049777
# 2021-07-01               NaN           -0.140236
# 2021-10-01               NaN            0.114529
# 2022-01-01               NaN            0.369393
#
# [161 rows x 5 columns]
